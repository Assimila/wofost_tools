# %%
import sys
sys.path.insert(0,'/home/acornelius/')
from startup import *
# %matplotlib inline

# %%
from cofost import cofost

# %%
# initizalise cofost
inst = cofost(woroot+'cabo/henan_s01HB*',
             woroot+'params/henan_crop_params.CAB',
             woroot+'params/Hengshui.soil',
             dt.date(2017,10,15),
             dt.date(2018,5,15))

# %%
# Process all the years in the data, with the same cropping calender
inst.Process()

# %%
# Display something
inst.Display('TWSO')

# %%
# Display Something else
inst.Display('TAGP')

# %%
# if we want, we can export the data to a csv
inst.Export_Summary('cofost_demonstation.csv')

# %%
# the output looks like this
pa.read_csv('cofost_demonstation.csv')
# Out:
#                  Unnamed: 0 current_dev_stage  current_twlv  current_twrt  \
# 0   1995-10-15 - 1996-05-15          anthesis      3181.896      2086.435
# 1   1996-10-15 - 1997-05-15          anthesis      2607.297      1707.511
# 2   1997-10-15 - 1998-05-15          anthesis      3044.696      1959.615
# 3   1998-10-15 - 1999-05-15          anthesis      2767.511      1818.381
# 4   1999-10-15 - 2000-05-15          anthesis      3101.609      2007.245
# 5   2000-10-15 - 2001-05-15          anthesis      3346.666      2151.122
# 6   2001-10-15 - 2002-05-15          anthesis      2857.616      1858.646
# 7   2002-10-15 - 2003-05-15          anthesis      3204.002      2105.056
# 8   2003-10-15 - 2004-05-15          anthesis      2838.913      1807.184
# 9   2004-10-15 - 2005-05-15          anthesis      3120.996      1996.829
# 10  2005-10-15 - 2006-05-15          anthesis      2851.021      1873.557
# 11  2006-10-15 - 2007-05-15          anthesis      2667.343      1761.682
# ...
